# %% [markdown]
# # 哈希表简介

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 哈希函数

# %% [markdown]
# # 哈希冲突

# %% [markdown]
# # 哈希表总结

# %% [markdown]
# - **哈希表**：通过键key和映射函数Hash(key)计算出对应的值value，value即为key在哈希表中的存储位置。
# - **哈希函数**：将key映射为哈希表中的存储位置。
# - **哈希冲突**：不同的key可能通过哈希函数映射到同一个存储位置。
# 哈希表的两个核心问题是：**「哈希函数的构建」** 和 **「哈希冲突的解决方法」**。
# - 常用的哈希函数：直接定址法、除留余数法、平方取中法、基数转换法、数字分析法、折叠法、随机数法、乘积法、点积法等。
# - 常用的哈希冲突解决方法：开放地址法和链地址法。
